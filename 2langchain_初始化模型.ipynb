# %% [markdown]
# # 1.deepseek-init-chat-model

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
load_dotenv()

model = init_chat_model(model="deepseek-chat")

print(model)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x11203cd90> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11203cca0> root_client=<openai.OpenAI object at 0x11202a610> root_async_client=<openai.AsyncOpenAI object at 0x11203c160> model_name='deepseek-chat' model_kwargs={} api_key=SecretStr('**********') api_base='https://api.deepseek.com/v1'

# %% [markdown]
# # 2.阿里

# %%
import os
base_url = os.getenv("DASHSCOPE_API_BASE")
api_key = os.getenv("DASHSCOPE_API_KEY")
qian_model = init_chat_model(
    model="qween-max",
    model_provider="openai",
    api_key=api_key,
    base_url=base_url
)
print(type(qian_model))
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>

# %% [markdown]
# # 3.使用model类

# %%
from langchain_community.chat_models.tongyi import ChatTongyi
model_tongyi = ChatTongyi(model="qween-max") # type: ignore
print(type(model_tongyi))
# Out:
# <class 'langchain_community.chat_models.tongyi.ChatTongyi'>
